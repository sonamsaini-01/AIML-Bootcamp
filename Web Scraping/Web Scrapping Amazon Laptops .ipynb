# %%
from IPython.display import HTML, display

cover_page = """
<div style="width: 100%; height: 210px; background-color: #FAF8F5; border-radius: 6px; box-shadow: 0 3px 12px rgba(0,0,0,0.05); display: flex; flex-direction: column; justify-content: center; align-items: center; text-align: center; border: 2px solid #EAE3DA;">
    <div style="font-size: 13px; color: #7E8D7F; margin-bottom: 4px; letter-spacing: 2px;">✦ &nbsp; 🌐 &nbsp; ✦</div>
    <h1 style="margin: 0; font-family: 'Georgia', serif; font-size: 38px; font-weight: normal; color: #2C2A29; letter-spacing: 1.5px;">Web Scraping</h1>
    <div style="width: 80px; height: 1px; background: #A09182; margin: 10px 0;"></div>
    <div style="font-family: 'Brush Script MT', 'Lucida Handwriting', cursive; font-size: 25px; color: #5C554F;">Sonam</div>
</div>
"""
display(HTML(cover_page))
# Out:
# <div style="width: 100%; height: 210px; background-color: #FAF8F5; border-radius: 6px; box-shadow: 0 3px 12px rgba(0,0,0,0.05); display: flex; flex-direction: column; justify-content: center; align-items: center; text-align: center; border: 2px solid #EAE3DA;">
#     <div style="font-size: 13px; color: #7E8D7F; margin-bottom: 4px; letter-spacing: 2px;">✦ &nbsp; 🌐 &nbsp; ✦</div>
#     <h1 style="margin: 0; font-family: 'Georgia', serif; font-size: 38px; font-weight: normal; color: #2C2A29; letter-spacing: 1.5px;">Web Scraping</h1>
#     <div style="width: 80px; height: 1px; background: #A09182; margin: 10px 0;"></div>
#     <div style="font-family: 'Brush Script MT', 'Lucida Handwriting', cursive; font-size: 25px; color: #5C554F;">Sonam</div>
# </div>

# %% [markdown]
# <div style="background:#4B0082;
# padding:20px;
# border-radius:12px;
# color:White;
# text-align:center;">
#
# <h1>Team Name : Power Players </h1>
# </div>

# %% [markdown]
# <div style="
#     background: #FADAAD;
#     color: #6D517A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     Website Name : Amazon
#
# </div>

# %% [markdown]
# <div style="
#     background: #FADAAD;
#     color: #6D517A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     🌐 Process Of Web Scraping 🌐
#
# </div>

# %% [markdown]
# The 6 Stages of Web Scraping ->
# 1. Sending the HTTP Request
# - The scraper acts as a digital client, dispatching an HTTP GET request to the target web server’s URL.
#
# 2. Retrieving Web Page Content
# - The server captures the request and responds by delivering the raw code of the webpage, most commonly in HTML format.
#
# 3. Parsing the HTML Content
# - The unstructured raw HTML is fed into dedicated parsing tools (such as BeautifulSoup or Scrapy) to translate the code into a structured, navigable tree of elements.
#
# 4. Extracting the Data
# - Searches the parsed tree using predefined rules or locators to grab only the specific data points you want (e.g., product prices, headlines).
#
# 5. Storing the Data
# - The captured data is cleaned and exported into a permanent, structured format for analysis—typically CSV, JSON, or directly into a Database.
#
# 6. Anti-Scraping Defenses: Bypassing IP blocks, rate-limits, or CAPTCHAs via rotating proxies and headers.
# - Legal & Ethical Compliance: Abiding by the site's robots.txt rules, Terms of Service, and regional data privacy laws.

# %% [markdown]
# <div style="
#     background: #FADADD;
#     color: #6D517A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     🌐 Step 1 : Sending HTTP Request 🌐
#
# </div>

# %%
import requests

# %%
url = "https://www.amazon.in/s?k=laptop&crid=YLH7SZQM1WE6&sprefix=laptop%2Caps%2C610&ref=nb_sb_noss_2"
headers={ "User-Agent": "Mozilla/5.0(Windows NT 10.0; Win64 ; x64) appleWebKit/537.36 (KHTML ,Like Gecko Chrome/91.0.4472.124 Safari/537.36"}
response= requests.get(url , headers=headers)
response.status_code
# Out:
# 200

# %% [markdown]
# <div style="
#     background: #FADADD;
#     color: #6D597A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     🌐 Step 2 : Extract html content 🌐
#
# </div>

# %%
html_code = response.text
#html_code

# %% [markdown]
# <div style="
#     background: #FADADD;
#     color: #6D597A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     🌐 Step 3 : Parsing the Html content 🌐
#
# </div>

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
soup = BeautifulSoup(html_code, "html.parser")
#soup

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <!-- sp:end-feature:csm:head-open-part1 -->
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="preconnect"/>
#   <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
#   <!-- sp:end-feature:cs-optimization -->
#   <!-- sp:feature:csm:head-open-part2 -->
#   <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
laptops=soup.find_all('div', class_ ='puisg-col-inner')
laptops
# Out:
# [<div class="puisg-col-inner"><div class="a-section a-spacing-none aok-relative puis-status-badge-container s-list-status-badge-container"></div><div class="s-product-image-container aok-relative s-text-center s-image-overlay-grey puis-image-overlay-grey s-padding-left-small s-padding-right-small puis-flex-expand-height puis puis-v2lstc5p0oad1j2pqjic4rhsbvr" data-cy="image-container"><div class="aok-relative"><span class="rush-component" data-component-type="s-product-image" data-render-id="rzkmkhml30eqn25siiwvnoicq2" data-version-id="v2lstc5p0oad1j2pqjic4rhsbvr"><a aria-hidden="true" class="a-link-normal s-no-outline" href="/sspa/click?ie=UTF8&amp;spc=MTozNjA1NjEwMjc2OTYwMTYxOjE3ODIzMDkwNjI6c3BfYXRmOjMwMTEzNTEwODU3NDYzMjo6MDo6&amp;url=%2FApple-2026-MacBook-Laptop-chip%2Fdp%2FB0GR1PXKTQ%2Fref%3Dsr_1_1_sspa%3Fcrid%3DYLH7SZQM1WE6%26dib%3DeyJ2IjoiMSJ9.W_O_tFUJJtIXz-M315QEWhnqq6Z6qdO5C5PrAQo7_2rzB7iPMokMisrlAL1Y-EkOQMArq696247A9kCyfYTi-QjiE9VWxz-eSq9DdxGLB8mblO5LLaUpqXKhgjmxLQ7_2_4ZFNQzm
# ...

# %% [markdown]
# <div style="
#     background: #FADADD;
#     color: #6D597A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     🌐 Step 4 : Extracting Data 🌐
#
# </div>

# %%
products = soup.find_all("div", attrs={"data-component-type": "s-search-result"})

# %%
data = []

for product in products:

    # Title
    title = product.select_one("h2 span")
    title = title.get_text(strip=True) if title else "N/A"

    # Price
    price = product.find("span", class_="a-price-whole")
    price = price.get_text(strip=True) if price else "N/A"

    # Rating
    rating = product.find("span", class_="a-icon-alt")
    rating = rating.get_text(strip=True) if rating else "N/A"

    # Image URL
    img = product.find("img")
    image_url = img.get("src") if img else "N/A"

    # Store data
    data.append({
        "Title": title,
        "Price": price,
        "Rating": rating,
        "Image URL": image_url
    })

# %%
df = pd.DataFrame(data)

print(df.head())
# Out:
#                                                Title     Price  \
# 0  Apple 2026 MacBook Air 15″ Laptop with M5 chip...  1,57,990
# 1  Apple 2026 MacBook Air 13″ Laptop with M5 chip...  1,31,990
# 2  Acer Smartchoice Aspire One, Intel Core Celero...    35,990
# 3  ASUS Vivobook 15, Smartchoice,Intel Core i5 13...    60,990
# 4  HP 15, Intel Core Ultra 5 125H (16GB DDR5, 1TB...    78,990
#
#                Rating                                          Image URL
# 0  5.0 out of 5 stars  https://m.media-amazon.com/images/I/71DZqJsOgF...
# 1  5.0 out of 5 stars  https://m.media-amazon.com/images/I/71kKQjKzW1...
# 2  3.2 out of 5 stars  https://m.media-amazon.com/images/I/81BEfyD0qe...
# 3  4.2 out of 5 stars  https://m.media-amazon.com/images/I/818iNyzckG...
# 4  4.0 out of 5 stars  https://m.media-amazon.com/images/I/612wzTFNDs...

# %% [markdown]
# <div style="
#     background: #FADADD;
#     color: #6D597A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     🌐 Step 5 : Storing Data 🌐
#
# </div>

# %%
df.to_csv("webscrap_amazon_laptops.csv", index=False, encoding="utf-8")

# %% [markdown]
# <div style="
# background: linear-gradient(135deg, #4FF6E5, #7C3AED);
# padding: 25px;
# border-radius: 15px;
# text-align: center;
# color: white;
# font-size: 32px;
# font-weight: bold;
# ">
# 🙏 THANK YOU 🙏
# <br><br>
# <span style="font-size:20px;">
#     for Visiting the project
# </span>
# </div>
