# %% [markdown]
# <div style="
#     background: #FADADD;
#     color: #6D597A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     Website Name : Wikipedia list of companies
#
# </div>

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://en.wikipedia.org/wiki/List_of_largest_companies_by_revenue"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, "html.parser")

# Find the first table
table = soup.find("table", class_="wikitable")

# Extract headers
headers = [th.get_text(strip=True) for th in table.find_all("th")]

# %%
rows = []
for tr in table.find_all("tr"):
    cells = [cell.get_text(strip=True) for cell in tr.find_all(["th", "td"])]
    if len(cells) == 8:   # Only keep rows with company data
        rows.append(cells)

# %%
df = pd.DataFrame(rows[1:], columns=rows[0])
df
# Out:
#      2                                  Walmart                  Retail   713  \
# 0    5     China National Petroleum Corporation                     476  25.2
# 1    8                                 Alphabet  Information technology   402
# 2    9                       UnitedHealth Group              Healthcare   400
# 3   10                       Berkshire Hathaway              Financials   371
# 4   11                               CVS Health              Healthcare   357
# 5   19                                Microsoft  Information technology   281
# 6   20                                  Cencora              Healthcare   262
# 7   23                           JPMorgan Chase              Financials   239
# 8   24  Industrial and Commercial Bank of China                     222  51.4
# 9   35                                  Foxconn                     197   4.5
# 10  40                       Ford Motor Company              Automotive   176
# ...

# %%
df.to_csv("largest_companies_by_revenue.csv", index=False)

print("Saved as largest_companies_by_revenue.csv")
# Out:
# Saved as largest_companies_by_revenue.csv

# %% [markdown]
# <div style="
#     background: #FADADD;
#     color: #6D597A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     🌐 Thank You 🌐
#
# </div>
