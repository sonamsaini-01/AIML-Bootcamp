# %% [markdown]
# <div style="
#     background: #FADAA4;
#     color: #AD597A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     Website Name : gyansetu.CodroidHub
#
# </div>

# %% [markdown]
# <div style="
#     background: #FADADD;
#     color: #6D597A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-weight:bold;
#     font-size:20px;
#     border: 2px solid #E8C7D1;">
#
#     🌐 Step : Imports
#     cURL API in Headers
#     Check Status Code 🌐
#
#
# </div>

# %%
import requests
import pandas as pd
import json

# %%
url = "https://gyansetu.codroidhub.com/api/universities"

# %%
response = requests.get(url)

print("Status Code:", response.status_code)
# Out:
# Status Code: 200

# %% [markdown]
# <div style="
#     background: #FADADD;
#     color: #6D597A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     🌐 Step : Create json object
#                Output Keys  🌐
#
# </div>

# %%
data = response.json()

print(type(data))
# Out:
# <class 'dict'>

# %%
print("Total Universities:", len(data))
# Out:
# Total Universities: 2

# %%
df = pd.DataFrame(data)

df
# Out:
#    success                                               data
# 0     True  {'_id': '6913687aea053fdf7ba50271', 'name': 'G...
# 1     True  {'_id': '6917f09c75b79a7d34e91e0d', 'name': 'A...
# 2     True  {'_id': '6917f0f675b79a7d34e92096', 'name': 'P...
# 3     True  {'_id': '6917fd16a0ffbe9cae53d023', 'name': 'S...
# 4     True  {'_id': '6917fd42a0ffbe9cae53d029', 'name': 'C...
# 5     True  {'_id': '6917fd71a0ffbe9cae53d02f', 'name': 'C...
# 6     True  {'_id': '697c43e15dfa2433d3adc908', 'name': 'J...
# 7     True  {'_id': '69b77f3a03b91977be726342', 'name': 'J...
# 8     True  {'_id': '6a1e9b2087f79be09303a6d9', 'name': 'G...

# %% [markdown]
# <div style="
#     background: #FADADD;
#     color: #6D597A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     🌐 Step : Save To CSV 🌐
#
# </div>

# %%
df.to_csv("universitiesapi.csv", index=False)

print("CSV Saved Successfully")
# Out:
# CSV Saved Successfully

# %% [markdown]
# <div style="
#     background: #FADADD;
#     color: #6D597A;
#     padding: 12px;
#     border-radius: 10px;
#     text-align: center;
#     font-size: 24px;
#     font-weight: bold;
#     border: 2px solid #E8C7D1;">
#
#     🌐 THANKYOU 🌐
#
# </div>
